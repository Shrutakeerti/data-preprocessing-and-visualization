# %%
import matplotlib.pyplot as plt
x=['python','C','C++','Java']
y=[1.9,2.7,1.8,3.9]
z=['Pro','Average','Noob','Fast']
plt.xlabel("Languages",fontsize=18)
plt.ylabel("Number",fontsize=20)
plt.title("Happy happy happy")
c=['b','r','y','g']
plt.bar(x,y,width=0.4,color='r',align='center',edgecolor='black',linewidth=6,label='Programs')
plt.bar(x,z,width=0.4,color='g',align='center',edgecolor='black',linewidth=6,label='Programs')
plt.legend()
plt.show()

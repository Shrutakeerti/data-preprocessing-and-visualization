# %% [markdown]
# ##Scatter plot

# %%
import matplotlib.pyplot as plt
day=[1,3,5,7,9,11]
no=[12,14,11,15,17,18]
plt.title("Scatter Plot", fontsize=14)
plt.xlabel("Day",fontsize=15)
plt.ylabel("No",fontsize=15)
plt.scatter(day,no)
plt.show()

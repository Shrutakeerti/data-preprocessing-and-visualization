# %%
import matplotlib.pyplot as plt
x=['python','C','C++','Java']
y=[93,76,89,91]
z=['Pro','Average','Noob','Fast']
plt.xlabel("Languages",fontsize=18)
plt.ylabel("Number",fontsize=20)
plt.title("Happy happy happy")
c=['b','r','y','g']
plt.bar(x,y,width=0.4,color=c,align='center',edgecolor='black',linewidth=6,linestyle=':',alpha=0.4,label='Programs')
plt.legend()
plt.show()
